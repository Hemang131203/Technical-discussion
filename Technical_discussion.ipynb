# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemang131203/Technical-discussion/blob/main/Technical_discussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello():
  return x + y
